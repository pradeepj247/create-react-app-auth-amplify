# %% [markdown]
# <a href="https://colab.research.google.com/github/pradeepj247/create-react-app-auth-amplify/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jahongir7174/ByteTrack.git
# Out:
# Cloning into 'ByteTrack'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 19 (delta 0), reused 0 (delta 0), pack-reused 18 (from 1)
# Receiving objects: 100% (19/19), 47.86 MiB | 11.52 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# %cd ByteTrack
# !mkdir -p demo
# !mkdir -p weights
# Out:
# /content/ByteTrack

# %%
# !echo "opencv-python-headless==999.0.0" > constraints.txt

# %%
# !pip install --no-cache-dir opencv-python==4.10.0.84
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 170.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.12.0.88
#     Uninstalling opencv-python-4.12.0.88:
#       Successfully uninstalled opencv-python-4.12.0.88
# ...

# %%
# !pip install ultralytics --constraint constraints.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 73.7 MB/s eta 0:00:00
# ...

# %%
# !pip install lapx
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 83.4 MB/s eta 0:00:00
# ...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !wget https://raw.githubusercontent.com/Jumabek/LITE/main/demo/VIRAT_S_010204_07_000942_000989.mp4 \
     -O demo/VIRAT_S_010204_07_000942_000989.mp4
# Out:
# --2025-11-13 15:02:01--  https://raw.githubusercontent.com/Jumabek/LITE/main/demo/VIRAT_S_010204_07_000942_000989.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7457845 (7.1M) [application/octet-stream]
# Saving to: ‘demo/VIRAT_S_010204_07_000942_000989.mp4’
#
# demo/VIRAT_S_010204 100%[===================>]   7.11M  --.-KB/s    in 0.02s
#
# 2025-11-13 15:02:03 (354 MB/s) - ‘demo/VIRAT_S_010204_07_000942_000989.mp4’ saved [7457845/7457845]

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8s.pt \
     -O weights/yolov8s.pt
# Out:
# --2025-11-13 15:02:23--  https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8s.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import numpy as np
import cv2

print("NumPy:", np.__version__)
print("OpenCV:", cv2.__version__)
# Out:
# NumPy: 2.0.2
# OpenCV: 4.10.0

# %%
# !python main.py \
    --input_video demo/palace.mp4 \
    --output_video demo/output_palace1.mp4 \
    --weights weights/yolov8s.pt
# Out:
# 📦 Loading YOLOv8 model: weights/yolov8s.pt
# 🎥 Processing: demo/palace.mp4
# 💾 Writing output to: demo/output_palace1.mp4
#   → Frame 50 | Avg FPS: 44.08
#   → Frame 100 | Avg FPS: 51.26
#   → Frame 150 | Avg FPS: 57.75
#   → Frame 200 | Avg FPS: 61.13
#   → Frame 250 | Avg FPS: 63.12
#   → Frame 300 | Avg FPS: 64.11
#
# ✅ Done! Total frames: 329
# ⚡ Average Effective FPS: 64.68
# 🎉 Output saved to: demo/output_palace1.mp4

# %%
# !wget https://raw.githubusercontent.com/HanGuangXin/ByteTrack_ReID/master/videos/palace.mp4 \
     -O demo/palace.mp4
# Out:
# --2025-11-13 15:37:32--  https://raw.githubusercontent.com/HanGuangXin/ByteTrack_ReID/master/videos/palace.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5909113 (5.6M) [application/octet-stream]
# Saving to: ‘demo/palace.mp4’
#
# demo/palace.mp4     100%[===================>]   5.63M  --.-KB/s    in 0.02s
#
# 2025-11-13 15:37:33 (279 MB/s) - ‘demo/palace.mp4’ saved [5909113/5909113]

# %%
# !wget https://github.com/KaiyangZhou/deep-person-reid/releases/download/osnet_x0_25_msmt/osnet_x0_25_msmt.pth \
    -O weights/osnet_x0_25_msmt.pth
# Out:
# --2025-11-13 15:42:07--  https://github.com/KaiyangZhou/deep-person-reid/releases/download/osnet_x0_25_msmt/osnet_x0_25_msmt.pth
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-11-13 15:42:07 ERROR 404: Not Found.

# %%
import torchvision
print("TorchVision version:", torchvision.__version__)
# Out:
# TorchVision version: 0.23.0+cu126

# %%
# !pip install torchreid
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torchreid: filename=torchreid-0.2.5-py3-none-any.whl size=144324 sha256=8142b3c18a87bac05724f5182fc3c45c909bfe0a56b8063320d24b594037f319
#   Stored in directory: /root/.cache/pip/wheels/5c/86/ff/80a1b78a90df470cbb12c075bf189ad33f1a41a881cf9e9a09
# Successfully built torchreid
# ...

# %%
# !python3 main.py --input_video demo/VIRAT.mp4 --output_video demo/virat_out.mp4 --weights yolov8s.pt
# Out:
# /usr/local/lib/python3.12/dist-packages/torchreid/reid/metrics/rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763052149.047440   27481 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763052149.057218   27481 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763052149.081299   27481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
